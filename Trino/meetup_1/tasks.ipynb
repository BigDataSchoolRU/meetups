# %% [markdown]
# http://www.bigdataschool.ru
#
# <img src="logo.png" align="right">

# %% [markdown]
# # Задачки на порешать

# %% [markdown]
# <hr style="border:2px solid #294A70"> </hr>
#
# <h3 style="color: #294A70">Практические материалы</h3>
#
# <div style="color:red; text-align: right"> Версия 1.02 от 10 января 2025 </div>

# %%
from trsql_h import _psql, _sql

# %%
_psql("show catalogs")
# Out:
# <pre style="white-space: pre !important;"> Catalog
# ----------
#  hive
#  ice
#  kafka
#  memory
#  postgres
#  system
#  tpcds
# (7 rows)
# </pre>

# %% [markdown]
# ## PostgreSQL

# %%
_psql("show tables in postgres.public")
# Out:
# <pre style="white-space: pre !important;">     Table
# ----------------
#  countries
#  countries_new
#  quotes_changes
#  testtab
# (4 rows)
# </pre>

# %%
_sql("select * from postgres.public.countries limit 3")
# Out:
#         country                               region  population     area  \
# 0  Afghanistan         ASIA (EX. NEAR EAST)             31056997   647500
# 1      Albania   EASTERN EUROPE                          3581655    28748
# 2      Algeria   NORTHERN AFRICA                        32930091  2381740
#
#   popdensity coastline netmigration infantmortality   gdp literacy phones  \
# 0       48,0      0,00        23,06          163,07   700     36,0    3,2
# 1      124,6      1,26        -4,93           21,52  4500     86,5   71,2
# 2       13,8      0,04        -0,39              31  6000     70,0   78,1
#
#   arable crops  other  climate birthrate deathrate agriculture industry  \
# 0  12,13  0,22  87,65        1      46,6     20,34        0,38     0,24
# 1  21,09  4,42  74,49        3     15,11      5,22       0,232    0,188
# 2   3,22  0,25  96,53        1     17,14      4,61       0,101      0,6
#
#   service
# 0    0,38
# 1   0,579
# 2   0,298

# %% [markdown]
# ## Задача 1: самые большие и самые маленькие страны

# %% [markdown]
# Выведите следующую таблицу
#
# * регион
# * страна с самым маленьким населением в регионе
# * население этой страны
# * страна с самым большим населением в регионе
# * население этой страны
#
# Пусть таблица будет упорядочена по названию региона

# %% [markdown]
# ## Задача 2: средний чек

# %% [markdown]
# Используйте встроенный источник `tpcds.sf1`

# %%
_psql("show tables in tpcds.sf1")
# Out:
# <pre style="white-space: pre !important;">         Table
# ------------------------
#  call_center
#  catalog_page
#  catalog_returns
#  catalog_sales
#  customer
#  customer_address
#  customer_demographics
#  date_dim
#  dbgen_version
#  household_demographics
#  income_band
#  inventory
#  item
#  promotion
#  reason
#  ship_mode
#  store
#  store_returns
#  store_sales
#  time_dim
#  warehouse
#  web_page
#  web_returns
#  web_sales
#  web_site
# (25 rows)
# </pre>

# %%
_psql("describe tpcds.sf1.store_sales")
# Out:
# <pre style="white-space: pre !important;">        Column         |     Type     | Extra | Comment
# -----------------------+--------------+-------+---------
#  ss_sold_date_sk       | bigint       |       |
#  ss_sold_time_sk       | bigint       |       |
#  ss_item_sk            | bigint       |       |
#  ss_customer_sk        | bigint       |       |
#  ss_cdemo_sk           | bigint       |       |
#  ss_hdemo_sk           | bigint       |       |
#  ss_addr_sk            | bigint       |       |
#  ss_store_sk           | bigint       |       |
#  ss_promo_sk           | bigint       |       |
#  ss_ticket_number      | bigint       |       |
#  ss_quantity           | integer      |       |
#  ss_wholesale_cost     | decimal(7,2) |       |
#  ss_list_price         | decimal(7,2) |       |
#  ss_sales_price        | decimal(7,2) |       |
#  ss_ext_discount_amt   | decimal(7,2) |       |
#  ss_ext_sales_price    | decimal(7,2) |       |
# ...

# %% [markdown]
# Выведите информацию о чеках выше среднего - таблицу со следующими колонками
#
# * номер чека ( ss_ticket_number )
# * дату чека (см. таблицу date_dim)
# * сумму чека (сумма поля ss_ext_sales_price для всех строк чека)
# * сумму среднего чека за день
#
# В таблицу необходимо включать чеки за ноябрь 1998 года, таблица должна быть отсортирована по возрастанию даты чека, для одинаковых дат - по возрастанию номера чека.

# %% [markdown]
# <hr style="border:2px solid #294A70"> </hr>
#
# <div style="text-align: center"> © ООО «Учебный центр «Коммерсант», 2024 </div>
#
# <div style="text-align: center"> info@bigdataschool.ru, +7(495) 41-41-121 </div>
